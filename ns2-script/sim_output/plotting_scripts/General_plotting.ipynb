# %% [markdown]
# # General Plotting

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from collections import OrderedDict
import matplotlib.pyplot as plt

# %%
Directory = "d_tcp_1m_and_10k"

# %% [markdown]
# ### 2*1Mbps+0.01Mbps+1Mbps with TCP Reno

# %% [markdown]
# ### HCS

# %%
th_0_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_0.txt'%(Directory), header=None)
th_0_HCS.columns = ['Timestamp', 'Throughput']

th_1_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_1.txt'%(Directory), header=None)
th_1_HCS.columns = ['Timestamp', 'Throughput']

th_2_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_2.txt'%(Directory), header=None)
th_2_HCS.columns = ['Timestamp', 'Throughput']

th_3_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_3.txt'%(Directory), header=None)
th_3_HCS.columns = ['Timestamp', 'Throughput']

# %%
th_0_HCS.head()
# Out:
#    Timestamp  Throughput
# 0       0.11        0.00
# 1       0.13       16.92
# 2       0.13      374.56
# 3       0.15      427.13
# 4       0.15      576.29

# %%
print("th0_HCS.shape = ", th_0_HCS.shape)
print("th1_HCS.shape = ", th_1_HCS.shape)
print("th2_HCS.shape = ", th_2_HCS.shape)
print("th3_HCS.shape = ", th_3_HCS.shape)
# Out:
# th0_HCS.shape =  (1917, 2)
# th1_HCS.shape =  (1916, 2)
# th2_HCS.shape =  (25, 2)
# th3_HCS.shape =  (1921, 2)

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
plt.ylim(-50, 2000)
plt.plot(th_0_HCS['Timestamp'], th_0_HCS['Throughput'], color='red', label='th0_HCS')
plt.plot(th_1_HCS['Timestamp'], th_1_HCS['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_2_HCS['Timestamp'], th_2_HCS['Throughput'], color='green', label='th2_HCS')
plt.plot(th_3_HCS['Timestamp'], th_3_HCS['Throughput'], color='orange', label='th3_HCS')

# %%
th_com_0_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_combine_0.txt'%(Directory), header=None)
th_com_0_HCS.columns = ['Timestamp', 'Throughput']

th_com_1_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_combine_1.txt'%(Directory), header=None)
th_com_1_HCS.columns = ['Timestamp', 'Throughput']

th_com_2_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_combine_2.txt'%(Directory), header=None)
th_com_2_HCS.columns = ['Timestamp', 'Throughput']

th_com_3_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_combine_3.txt'%(Directory), header=None)
th_com_3_HCS.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_com_0_HCS['Timestamp'], th_com_0_HCS['Throughput'], color='red', label='th0_HCS')
plt.plot(th_com_1_HCS['Timestamp'], th_com_1_HCS['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_com_2_HCS['Timestamp'], th_com_2_HCS['Throughput'], color='green', label='th2_HCS')
plt.plot(th_com_3_HCS['Timestamp'], th_com_3_HCS['Throughput'], color='orange', label='th3_HCS')

# %%
th_short_0_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_short_0.txt'%(Directory), header=None)
th_short_0_HCS.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_1_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_short_1.txt'%(Directory), header=None)
th_short_1_HCS.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_2_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_short_2.txt'%(Directory), header=None)
th_short_2_HCS.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_3_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/throughput_short_3.txt'%(Directory), header=None)
th_short_3_HCS.columns = ['Timestamp', 'Throughput', 'Time Window']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_short_0_HCS['Timestamp'], th_short_0_HCS['Throughput'], color='red', label='th0_HCS')
plt.plot(th_short_1_HCS['Timestamp'], th_short_1_HCS['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_short_2_HCS['Timestamp'], th_short_2_HCS['Throughput'], color='green', label='th2_HCS')
plt.plot(th_short_3_HCS['Timestamp'], th_short_3_HCS['Throughput'], color='orange', label='th3_HCS')

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
#plt.xlim(0, 1)
plt.ylim(0, 0.08)
plt.plot(th_short_0_HCS['Timestamp'], th_short_0_HCS['Time Window'], color='red', label='th0_HCS')
plt.plot(th_short_1_HCS['Timestamp'], th_short_1_HCS['Time Window'], color='blue', label='th1_HCS')
plt.plot(th_short_2_HCS['Timestamp'], th_short_2_HCS['Time Window'], color='green', label='th2_HCS')
plt.plot(th_short_3_HCS['Timestamp'], th_short_3_HCS['Time Window'], color='orange', label='th3_HCS')

# %% [markdown]
# # AFQ10

# %%
th_0_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_0.txt'%(Directory), header=None)
th_0_AFQ10.columns = ['Timestamp', 'Throughput']

th_1_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_1.txt'%(Directory), header=None)
th_1_AFQ10.columns = ['Timestamp', 'Throughput']

th_2_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_2.txt'%(Directory), header=None)
th_2_AFQ10.columns = ['Timestamp', 'Throughput']

th_3_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_3.txt'%(Directory), header=None)
th_3_AFQ10.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ10")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_0_AFQ10['Timestamp'], th_0_AFQ10['Throughput'], color='red', label='th0_AFQ10')
plt.plot(th_1_AFQ10['Timestamp'], th_1_AFQ10['Throughput'], color='blue', label='th1_AFQ10')
plt.plot(th_2_AFQ10['Timestamp'], th_2_AFQ10['Throughput'], color='green', label='th2_AFQ10')
plt.plot(th_3_AFQ10['Timestamp'], th_3_AFQ10['Throughput'], color='orange', label='th3_AFQ10')

# %%
th_com_0_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_combine_0.txt'%(Directory), header=None)
th_com_0_AFQ10.columns = ['Timestamp', 'Throughput']

th_com_1_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_combine_1.txt'%(Directory), header=None)
th_com_1_AFQ10.columns = ['Timestamp', 'Throughput']

th_com_2_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_combine_2.txt'%(Directory), header=None)
th_com_2_AFQ10.columns = ['Timestamp', 'Throughput']

th_com_3_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_combine_3.txt'%(Directory), header=None)
th_com_3_AFQ10.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ10")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_com_0_AFQ10['Timestamp'], th_com_0_AFQ10['Throughput'], color='red', label='th0_AFQ10')
plt.plot(th_com_1_AFQ10['Timestamp'], th_com_1_AFQ10['Throughput'], color='blue', label='th1_AFQ10')
plt.plot(th_com_2_AFQ10['Timestamp'], th_com_2_AFQ10['Throughput'], color='green', label='th2_AFQ10')
plt.plot(th_com_3_AFQ10['Timestamp'], th_com_3_AFQ10['Throughput'], color='orange', label='th3_AFQ10')

# %%
th_short_0_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_short_0.txt'%(Directory), header=None)
th_short_0_AFQ10.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_1_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_short_1.txt'%(Directory), header=None)
th_short_1_AFQ10.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_2_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_short_2.txt'%(Directory), header=None)
th_short_2_AFQ10.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_3_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/throughput_short_3.txt'%(Directory), header=None)
th_short_3_AFQ10.columns = ['Timestamp', 'Throughput', 'Time Window']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_short_0_AFQ10['Timestamp'], th_short_0_AFQ10['Throughput'], color='red', label='th0_HCS')
plt.plot(th_short_1_AFQ10['Timestamp'], th_short_1_AFQ10['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_short_2_AFQ10['Timestamp'], th_short_2_AFQ10['Throughput'], color='green', label='th2_HCS')
plt.plot(th_short_3_AFQ10['Timestamp'], th_short_3_AFQ10['Throughput'], color='orange', label='th3_HCS')

# %% [markdown]
# ### AFQ100

# %%
th_0_AFQL100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_0.txt'%(Directory), header=None)
th_0_AFQL100.columns = ['Timestamp', 'Throughput']

th_1_AFQL100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_1.txt'%(Directory), header=None)
th_1_AFQL100.columns = ['Timestamp', 'Throughput']

th_2_AFQL100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_2.txt'%(Directory), header=None)
th_2_AFQL100.columns = ['Timestamp', 'Throughput']

th_3_AFQL100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_3.txt'%(Directory), header=None)
th_3_AFQL100.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ100")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_0_AFQL100['Timestamp'], th_0_AFQL100['Throughput'], color='red', label='th0_AFQ100')
plt.plot(th_1_AFQL100['Timestamp'], th_1_AFQL100['Throughput'], color='blue', label='th1_AFQ100')
plt.plot(th_2_AFQL100['Timestamp'], th_2_AFQL100['Throughput'], color='green', label='th2_AFQ100')
plt.plot(th_3_AFQL100['Timestamp'], th_3_AFQL100['Throughput'], color='orange', label='th3_AFQ100')

# %%
th_com_0_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_combine_0.txt'%(Directory), header=None)
th_com_0_AFQ100.columns = ['Timestamp', 'Throughput']

th_com_1_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_combine_1.txt'%(Directory), header=None)
th_com_1_AFQ100.columns = ['Timestamp', 'Throughput']

th_com_2_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_combine_2.txt'%(Directory), header=None)
th_com_2_AFQ100.columns = ['Timestamp', 'Throughput']

th_com_3_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_combine_3.txt'%(Directory), header=None)
th_com_3_AFQ100.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ10")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_com_0_AFQ100['Timestamp'], th_com_0_AFQ100['Throughput'], color='red', label='th0_AFQ100')
plt.plot(th_com_1_AFQ100['Timestamp'], th_com_1_AFQ100['Throughput'], color='blue', label='th1_AFQ100')
plt.plot(th_com_2_AFQ100['Timestamp'], th_com_2_AFQ100['Throughput'], color='green', label='th2_AFQ100')
plt.plot(th_com_3_AFQ100['Timestamp'], th_com_3_AFQ100['Throughput'], color='orange', label='th3_AFQ100')

# %%
th_com_0_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_combine_0.txt'%(Directory), header=None)
th_com_0_AFQ1000.columns = ['Timestamp', 'Throughput']

th_com_1_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_combine_1.txt'%(Directory), header=None)
th_com_1_AFQ1000.columns = ['Timestamp', 'Throughput']

th_com_2_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_combine_2.txt'%(Directory), header=None)
th_com_2_AFQ1000.columns = ['Timestamp', 'Throughput']

th_com_3_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_combine_3.txt'%(Directory), header=None)
th_com_3_AFQ1000.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ10")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_com_0_AFQ1000['Timestamp'], th_com_0_AFQ1000['Throughput'], color='red', label='th0_AFQ100')
plt.plot(th_com_1_AFQ1000['Timestamp'], th_com_1_AFQ1000['Throughput'], color='blue', label='th1_AFQ100')
plt.plot(th_com_2_AFQ1000['Timestamp'], th_com_2_AFQ1000['Throughput'], color='green', label='th2_AFQ100')
plt.plot(th_com_3_AFQ1000['Timestamp'], th_com_3_AFQ1000['Throughput'], color='orange', label='th3_AFQ100')

# %%
th_short_0_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_short_0.txt'%(Directory), header=None)
th_short_0_AFQ100.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_1_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_short_1.txt'%(Directory), header=None)
th_short_1_AFQ100.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_2_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_short_2.txt'%(Directory), header=None)
th_short_2_AFQ100.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_3_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/throughput_short_3.txt'%(Directory), header=None)
th_short_3_AFQ100.columns = ['Timestamp', 'Throughput', 'Time Window']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_short_0_AFQ100['Timestamp'], th_short_0_AFQ100['Throughput'], color='red', label='th0_HCS')
plt.plot(th_short_1_AFQ100['Timestamp'], th_short_1_AFQ100['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_short_2_AFQ100['Timestamp'], th_short_2_AFQ100['Throughput'], color='green', label='th2_HCS')
plt.plot(th_short_3_AFQ100['Timestamp'], th_short_3_AFQ100['Throughput'], color='orange', label='th3_HCS')

# %% [markdown]
# ### AFQ1000

# %%
th_0_AFQL1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_0.txt'%(Directory), header=None)
th_0_AFQL1000.columns = ['Timestamp', 'Throughput']

th_1_AFQL1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_1.txt'%(Directory), header=None)
th_1_AFQL1000.columns = ['Timestamp', 'Throughput']

th_2_AFQL1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_2.txt'%(Directory), header=None)
th_2_AFQL1000.columns = ['Timestamp', 'Throughput']

th_3_AFQL1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_3.txt'%(Directory), header=None)
th_3_AFQL1000.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ1000")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
plt.xlim(0, 1)
plt.ylim(-50, 2000)
plt.plot(th_0_AFQL1000['Timestamp'], th_0_AFQL1000['Throughput'], color='red', label='th0_AFQL1000')
plt.plot(th_1_AFQL1000['Timestamp'], th_1_AFQL1000['Throughput'], color='blue', label='th1_AFQL1000')
plt.plot(th_2_AFQL1000['Timestamp'], th_2_AFQL1000['Throughput'], color='green', label='th2_AFQL1000')
plt.plot(th_3_AFQL1000['Timestamp'], th_3_AFQL1000['Throughput'], color='orange', label='th3_AFQL1000')

# %%
th_short_0_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_short_0.txt'%(Directory), header=None)
th_short_0_AFQ1000.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_1_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_short_1.txt'%(Directory), header=None)
th_short_1_AFQ1000.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_2_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_short_2.txt'%(Directory), header=None)
th_short_2_AFQ1000.columns = ['Timestamp', 'Throughput', 'Time Window']

th_short_3_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/throughput_short_3.txt'%(Directory), header=None)
th_short_3_AFQ1000.columns = ['Timestamp', 'Throughput', 'Time Window']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.xlim(0, 1)
#plt.ylim(-50, 2000)
plt.plot(th_short_0_AFQ1000['Timestamp'], th_short_0_AFQ1000['Throughput'], color='red', label='th0_HCS')
plt.plot(th_short_1_AFQ1000['Timestamp'], th_short_1_AFQ1000['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_short_2_AFQ1000['Timestamp'], th_short_2_AFQ1000['Throughput'], color='green', label='th2_HCS')
plt.plot(th_short_3_AFQ1000['Timestamp'], th_short_3_AFQ1000['Throughput'], color='orange', label='th3_HCS')

# %% [markdown]
# ### DropTail with 1Mbps cbr

# %%
th_0_DropTail_1m = pd.read_table('../16_different_weights_udp/%s/DropTail/throughput_0.txt'%(Directory), header=None)
th_0_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_1_DropTail_1m = pd.read_table('../16_different_weights_udp/%s/DropTail/throughput_1.txt'%(Directory), header=None)
th_1_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_2_DropTail_1m = pd.read_table('../16_different_weights_udp/%s/DropTail/throughput_2.txt'%(Directory), header=None)
th_2_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_3_DropTail_1m = pd.read_table('../16_different_weights_udp/%s/DropTail/throughput_3.txt'%(Directory), header=None)
th_3_DropTail_1m.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQL1000")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_DropTail_1m['Timestamp'], th_0_DropTail_1m['Throughput'], color='red', label='th0_AFQL100')
plt.plot(th_1_DropTail_1m['Timestamp'], th_1_DropTail_1m['Throughput'], color='blue', label='th1_AFQL100')
plt.plot(th_2_DropTail_1m['Timestamp'], th_2_DropTail_1m['Throughput'], color='green', label='th2_AFQL100')
plt.plot(th_3_DropTail_1m['Timestamp'], th_3_DropTail_1m['Throughput'], color='orange', label='th3_AFQL100')

# %% [markdown]
# ## Delay
#
# ### HCS

# %%
delay_0_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/delay_0.txt'%(Directory), header=None)
delay_0_HCS.columns = ['Packet_Seq', 'Delay']

delay_1_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/delay_1.txt'%(Directory), header=None)
delay_1_HCS.columns = ['Packet_Seq', 'Delay']

delay_2_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/delay_2.txt'%(Directory), header=None)
delay_2_HCS.columns = ['Packet_Seq', 'Delay']

delay_3_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/delay_3.txt'%(Directory), header=None)
delay_3_HCS.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay HCS")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
plt.ylim(0, 0.2)
plt.plot(delay_0_HCS['Packet_Seq'], delay_0_HCS['Delay'], color='red', label='delay0_HCS')
plt.plot(delay_1_HCS['Packet_Seq'], delay_1_HCS['Delay'], color='blue', label='delay1_HCS')
plt.plot(delay_2_HCS['Packet_Seq'], delay_2_HCS['Delay'], color='green', label='delay2_HCS')
plt.plot(delay_3_HCS['Packet_Seq'], delay_3_HCS['Delay'], color='orange', label='delay3_HCS')

# %% [markdown]
# ### AFQ10

# %%
delay_0_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/delay_0.txt'%(Directory), header=None)
delay_0_AFQ10.columns = ['Packet_Seq', 'Delay']

delay_1_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/delay_1.txt'%(Directory), header=None)
delay_1_AFQ10.columns = ['Packet_Seq', 'Delay']

#delay_2_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/delay_2.txt'%(Directory), header=None)
#delay_2_AFQ10.columns = ['Packet_Seq', 'Delay']

delay_3_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/delay_3.txt'%(Directory), header=None)
delay_3_AFQ10.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQ10")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
#plt.ylim(0, 0.35)
plt.plot(delay_0_AFQ10['Packet_Seq'], delay_0_AFQ10['Delay'], color='red', label='delay0_AFQ10')
plt.plot(delay_1_AFQ10['Packet_Seq'], delay_1_AFQ10['Delay'], color='blue', label='delay1_AFQ10')
#plt.plot(delay_2_AFQ10['Packet_Seq'], delay_2_AFQ10['Delay'], color='green', label='delay2_AFQ10')
plt.plot(delay_3_AFQ10['Packet_Seq'], delay_3_AFQ10['Delay'], color='orange', label='delay3_AFQ10')

# %% [markdown]
# ### AFQ100

# %%
delay_0_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/delay_0.txt'%(Directory), header=None)
delay_0_AFQ100.columns = ['Packet_Seq', 'Delay']

delay_1_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/delay_1.txt'%(Directory), header=None)
delay_1_AFQ100.columns = ['Packet_Seq', 'Delay']

delay_2_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/delay_2.txt'%(Directory), header=None)
delay_2_AFQ100.columns = ['Packet_Seq', 'Delay']

delay_3_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/delay_3.txt'%(Directory), header=None)
delay_3_AFQ100.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQ10")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
#plt.ylim(0, 0.35)
plt.plot(delay_0_AFQ100['Packet_Seq'], delay_0_AFQ100['Delay'], color='red', label='delay0_AFQ100')
plt.plot(delay_1_AFQ100['Packet_Seq'], delay_1_AFQ100['Delay'], color='blue', label='delay1_AFQ100')
plt.plot(delay_2_AFQ100['Packet_Seq'], delay_2_AFQ100['Delay'], color='green', label='delay2_AFQ100')
plt.plot(delay_3_AFQ100['Packet_Seq'], delay_3_AFQ100['Delay'], color='orange', label='delay3_AFQ100')

# %% [markdown]
# ### AFQ1000

# %%
delay_0_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/delay_0.txt'%(Directory), header=None)
delay_0_AFQ1000.columns = ['Packet_Seq', 'Delay']

delay_1_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/delay_1.txt'%(Directory), header=None)
delay_1_AFQ1000.columns = ['Packet_Seq', 'Delay']

delay_2_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/delay_2.txt'%(Directory), header=None)
delay_2_AFQ1000.columns = ['Packet_Seq', 'Delay']

delay_3_AFQ1000 = pd.read_table('../16_different_weights_udp/%s/AFQ1000/delay_3.txt'%(Directory), header=None)
delay_3_AFQ1000.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQ10")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.ylim(0, 0.35)
plt.plot(delay_0_AFQ1000['Packet_Seq'], delay_0_AFQ1000['Delay'], color='red', label='delay0_AFQ100')
plt.plot(delay_1_AFQ1000['Packet_Seq'], delay_1_AFQ1000['Delay'], color='blue', label='delay1_AFQ100')
plt.plot(delay_2_AFQ1000['Packet_Seq'], delay_2_AFQ1000['Delay'], color='green', label='delay2_AFQ100')
plt.plot(delay_3_AFQ1000['Packet_Seq'], delay_3_AFQ1000['Delay'], color='orange', label='delay3_AFQ100')

# %% [markdown]
# ### DropTail

# %%
delay_0_DropTail = pd.read_table('../16_different_weights_udp/%s/DropTail/delay_0.txt'%(Directory), header=None)
delay_0_DropTail.columns = ['Packet_Seq', 'Delay']

delay_1_DropTail = pd.read_table('../16_different_weights_udp/%s/DropTail/delay_1.txt'%(Directory), header=None)
delay_1_DropTail.columns = ['Packet_Seq', 'Delay']

delay_2_DropTail = pd.read_table('../16_different_weights_udp/%s/DropTail/delay_2.txt'%(Directory), header=None)
delay_2_DropTail.columns = ['Packet_Seq', 'Delay']

delay_3_DropTail = pd.read_table('../16_different_weights_udp/%s/DropTail/delay_3.txt'%(Directory), header=None)
delay_3_DropTail.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay DropTail")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.ylim(0, 0.35)
plt.plot(delay_0_DropTail['Packet_Seq'], delay_0_DropTail['Delay'], color='red', label='delay0_DropTail')
plt.plot(delay_1_DropTail['Packet_Seq'], delay_1_DropTail['Delay'], color='blue', label='delay1_DropTail')
plt.plot(delay_2_DropTail['Packet_Seq'], delay_2_DropTail['Delay'], color='green', label='delay2_DropTail')
plt.plot(delay_3_DropTail['Packet_Seq'], delay_3_DropTail['Delay'], color='orange', label='delay3_DropTail')

# %% [markdown]
# ### Jitters

# %% [markdown]
# ### HCS

# %%
jitter_0_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/jitter_0.txt'%(Directory), header=None)
jitter_0_HCS.columns = ['Time', 'Jitter']

jitter_1_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/jitter_1.txt'%(Directory), header=None)
jitter_1_HCS.columns = ['Time', 'Jitter']

jitter_2_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/jitter_2.txt'%(Directory), header=None)
jitter_2_HCS.columns = ['Time', 'Jitter']

jitter_3_HCS = pd.read_table('../16_different_weights_udp/%s/HCS/jitter_3.txt'%(Directory), header=None)
jitter_3_HCS.columns = ['Time', 'Jitter']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time")
plt.ylabel("Jitter)")
plt.title("Jitter HCS")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
plt.ylim(-0.15, 0.15)
plt.plot(jitter_0_HCS['Time'], jitter_0_HCS['Jitter'], color='red', label='jitter0_HCS')
plt.plot(jitter_1_HCS['Time'], jitter_1_HCS['Jitter'], color='blue', label='jitter1_HCS')
plt.plot(jitter_2_HCS['Time'], jitter_2_HCS['Jitter'], color='green', label='jitter2_HCS')
plt.plot(jitter_3_HCS['Time'], jitter_3_HCS['Jitter'], color='orange', label='jitter3_HCS')

# %% [markdown]
# ### AFQ10

# %%
jitter_0_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/jitter_0.txt'%(Directory), header=None)
jitter_0_AFQ10.columns = ['Time', 'Jitter']

jitter_1_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/jitter_1.txt'%(Directory), header=None)
jitter_1_AFQ10.columns = ['Time', 'Jitter']

#jitter_2_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/jitter_2.txt'%(Directory), header=None)
#jitter_2_AFQ10.columns = ['Time', 'Jitter']

jitter_3_AFQ10 = pd.read_table('../16_different_weights_udp/%s/AFQ10/jitter_3.txt'%(Directory), header=None)
jitter_3_AFQ10.columns = ['Time', 'Jitter']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time")
plt.ylabel("Jitter)")
plt.title("Jitter HCS")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
plt.ylim(-0.15, 0.15)
plt.plot(jitter_0_AFQ10['Time'], jitter_0_AFQ10['Jitter'], color='red', label='jitter0_HCS')
plt.plot(jitter_1_AFQ10['Time'], jitter_1_AFQ10['Jitter'], color='blue', label='jitter1_HCS')
#plt.plot(jitter_2_AFQ10['Time'], jitter_2_AFQ10['Jitter'], color='green', label='jitter2_HCS')
plt.plot(jitter_3_AFQ10['Time'], jitter_3_AFQ10['Jitter'], color='orange', label='jitter3_HCS')

# %% [markdown]
# ### AFQ100

# %%
jitter_0_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/jitter_0.txt'%(Directory), header=None)
jitter_0_AFQ100.columns = ['Time', 'Jitter']

jitter_1_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/jitter_1.txt'%(Directory), header=None)
jitter_1_AFQ100.columns = ['Time', 'Jitter']

jitter_2_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/jitter_2.txt'%(Directory), header=None)
jitter_2_AFQ100.columns = ['Time', 'Jitter']

jitter_3_AFQ100 = pd.read_table('../16_different_weights_udp/%s/AFQ100/jitter_3.txt'%(Directory), header=None)
jitter_3_AFQ100.columns = ['Time', 'Jitter']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time")
plt.ylabel("Jitter)")
plt.title("Jitter HCS")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
#line.set_dashes((10, 4))
plt.ylim(-0.15, 0.15)
plt.plot(jitter_0_AFQ100['Time'], jitter_0_AFQ100['Jitter'], color='red', label='jitter0_HCS')
plt.plot(jitter_1_AFQ100['Time'], jitter_1_AFQ100['Jitter'], color='blue', label='jitter1_HCS')
plt.plot(jitter_2_AFQ100['Time'], jitter_2_AFQ100['Jitter'], color='green', label='jitter2_HCS')
plt.plot(jitter_3_AFQ100['Time'], jitter_3_AFQ100['Jitter'], color='orange', label='jitter3_HCS')

# %% [markdown]
# ### Average

# %%
mean_th_short_0_HCS = th_short_0_HCS['Throughput'].mean()
mean_th_short_1_HCS = th_short_1_HCS['Throughput'].mean()
mean_th_short_2_HCS = th_short_2_HCS['Throughput'].mean()
mean_th_short_3_HCS = th_short_3_HCS['Throughput'].mean()

mean_th_short_0_AFQ10 = th_short_0_AFQ10['Throughput'].mean()
mean_th_short_1_AFQ10 = th_short_1_AFQ10['Throughput'].mean()
mean_th_short_2_AFQ10 = th_short_2_AFQ10['Throughput'].mean()
mean_th_short_3_AFQ10 = th_short_3_AFQ10['Throughput'].mean()

mean_th_short_0_AFQ100 = th_short_0_AFQ100['Throughput'].mean()
mean_th_short_1_AFQ100 = th_short_1_AFQ100['Throughput'].mean()
mean_th_short_2_AFQ100 = th_short_2_AFQ100['Throughput'].mean()
mean_th_short_3_AFQ100 = th_short_3_AFQ100['Throughput'].mean()

# %%
var_th_short_0_HCS = th_short_0_HCS['Throughput'].var()
var_th_short_1_HCS = th_short_1_HCS['Throughput'].var()
var_th_short_2_HCS = th_short_2_HCS['Throughput'].var()
var_th_short_3_HCS = th_short_3_HCS['Throughput'].var()

var_th_short_0_AFQ10 = th_short_0_AFQ10['Throughput'].var()
var_th_short_1_AFQ10 = th_short_1_AFQ10['Throughput'].var()
var_th_short_2_AFQ10 = th_short_2_AFQ10['Throughput'].var()
var_th_short_3_AFQ10 = th_short_3_AFQ10['Throughput'].var()

var_th_short_0_AFQ100 = th_short_0_AFQ100['Throughput'].var()
var_th_short_1_AFQ100 = th_short_1_AFQ100['Throughput'].var()
var_th_short_2_AFQ100 = th_short_2_AFQ100['Throughput'].var()
var_th_short_3_AFQ100 = th_short_3_AFQ100['Throughput'].var()

#var_th_short_0_AFQ100 = th_short_0_HCS['Throughput'].var()
#var_th_short_1_AFQ100 = th_short_0_HCS['Throughput'].var()
#var_th_short_2_AFQ100 = th_short_0_HCS['Throughput'].var()
#var_th_short_3_AFQ100 = th_short_0_HCS['Throughput'].var()

# %%
std_th_short_0_HCS = np.std(th_short_0_HCS['Throughput'])
std_th_short_1_HCS = np.std(th_short_1_HCS['Throughput'])
std_th_short_2_HCS = np.std(th_short_2_HCS['Throughput'])
std_th_short_3_HCS = np.std(th_short_3_HCS['Throughput'])

std_th_short_0_AFQ10 = np.std(th_short_0_AFQ10['Throughput'])
std_th_short_1_AFQ10 = np.std(th_short_1_AFQ10['Throughput'])
std_th_short_2_AFQ10 = np.std(th_short_2_AFQ10['Throughput'])
std_th_short_3_AFQ10 = np.std(th_short_3_AFQ10['Throughput'])

std_th_short_0_AFQ100 = np.std(th_short_0_AFQ100['Throughput'])
std_th_short_1_AFQ100 = np.std(th_short_1_AFQ100['Throughput'])
std_th_short_2_AFQ100 = np.std(th_short_2_AFQ100['Throughput'])
std_th_short_3_AFQ100 = np.std(th_short_3_AFQ100['Throughput'])

std_th_short_0_AFQ1000 = np.std(th_short_0_AFQ1000['Throughput'])
std_th_short_1_AFQ1000 = np.std(th_short_1_AFQ1000['Throughput'])
std_th_short_2_AFQ1000 = np.std(th_short_2_AFQ1000['Throughput'])
std_th_short_3_AFQ1000 = np.std(th_short_3_AFQ1000['Throughput'])

# %%
mean_list_HCS = [mean_th_short_0_HCS, mean_th_short_1_HCS, mean_th_short_2_HCS, mean_th_short_3_HCS]
mean_list_AFQ10 = [mean_th_short_0_AFQ10, mean_th_short_1_AFQ10, mean_th_short_2_AFQ10, mean_th_short_3_AFQ10]
mean_list_AFQ100 = [mean_th_short_0_AFQ100, mean_th_short_1_AFQ100, mean_th_short_2_AFQ100, mean_th_short_3_AFQ100]
#var_list_HCS = [var_th_short_0_HCS, var_th_short_1_HCS, var_th_short_2_HCS, var_th_short_3_HCS]

mean_mark_list_HCS = ["Flow 0 mean HCS", "Flow 1 mean HCS", "Flow 2 mean HCS", "Flow 3 mean HCS"]
mean_mark_list_AFQ10 = ["Flow 0 mean AFQ10", "Flow 1 mean AFQ10", "Flow 2 mean AFQ10", "Flow 3 mean AFQ10"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]

#plt.bar(range(len(var_list_HCS)), tick_label=var_mark_list_HCS)
print(mean_list_HCS)
print(mean_list_AFQ10)
print(mean_list_AFQ100)
# Out:
# [1324.4717057903254, 1324.373397703579, 25.26719999999999, 1329.2450858927816]
# [1328.0973946958238, 1327.9954914196928, 0.0, 1330.1745511157603]
# [1652.5784382566476, 1675.223828756048, 1201.9182545454546, 1843.8077665544233]

# %%
var_list_HCS = [var_th_short_0_HCS, var_th_short_1_HCS, var_th_short_2_HCS, var_th_short_3_HCS]
var_list_AFQ10 = [var_th_short_0_AFQ10, var_th_short_1_AFQ10, var_th_short_2_AFQ10, var_th_short_3_AFQ10]
var_list_AFQ100 = [var_th_short_0_AFQ100, var_th_short_1_AFQ100, var_th_short_2_AFQ100, var_th_short_3_AFQ100]
#var_list_HCS = [var_th_short_0_HCS, var_th_short_1_HCS, var_th_short_2_HCS, var_th_short_3_HCS]

var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]
var_mark_list_AFQ10 = ["Flow 0 var AFQ10", "Flow 1 var AFQ10", "Flow 2 var AFQ10", "Flow 3 var AFQ10"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]

#plt.bar(range(len(var_list_HCS)), tick_label=var_mark_list_HCS)
print(var_list_HCS)
print(var_list_AFQ10)
print(var_list_AFQ100)
# Out:
# [6142.061750794403, 6615.60744938954, 3219.2156793333343, 8527.915874797874]
# [4757.766417401965, 4946.634783980224, 0.0, 3813.3761648941913]
# [510682.87708102126, 428613.5514626553, 742365.9820509576, 909164.047104721]

# %%
std_list_HCS = [std_th_short_0_HCS, std_th_short_1_HCS, std_th_short_2_HCS, std_th_short_3_HCS]
std_list_AFQ10 = [std_th_short_0_AFQ10, std_th_short_1_AFQ10, std_th_short_2_AFQ10, std_th_short_3_AFQ10]
std_list_AFQ100 = [std_th_short_0_AFQ100, std_th_short_1_AFQ100, std_th_short_2_AFQ100, std_th_short_3_AFQ100]
#var_list_HCS = [var_th_short_0_HCS, var_th_short_1_HCS, var_th_short_2_HCS, var_th_short_3_HCS]

std_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]
std_mark_list_AFQ10 = ["Flow 0 var AFQ10", "Flow 1 var AFQ10", "Flow 2 var AFQ10", "Flow 3 var AFQ10"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]
#var_mark_list_HCS = ["Flow 0 var HCS", "Flow 1 var HCS", "Flow 2 var HCS", "Flow 3 var HCS"]

#plt.bar(range(len(var_list_HCS)), tick_label=var_mark_list_HCS)
print(std_list_HCS)
print(std_list_AFQ10)
print(std_list_AFQ100)
# Out:
# [78.35086313534964, 81.31515619569295, 55.59178943117411, 92.32267632649852]
# [68.95862730579412, 70.31402727051292, 0.0, 61.736514691731784]
# [714.404470177888, 654.5095429371061, 860.0386441253405, 953.2333680881932]

# %%
plt.bar(range(len(std_list_HCS)), std_list_HCS, tick_label=std_mark_list_HCS)
# Out:
# <Container object of 4 artists>

# %%
#plt.figure(figsize=(15,8))
plt.xlabel("Scheduler Scheme")
plt.ylabel("Throughput Standard Devation")
plt.title("Throughput Standard Devation")
plt.legend()

#group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10"]
group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10", "AFQ:g=100"]
std_list_HCS = [std_th_short_0_HCS, std_th_short_1_HCS, std_th_short_2_HCS, std_th_short_3_HCS]
std_list_AFQ10 = [std_th_short_0_AFQ10, std_th_short_1_AFQ10, std_th_short_2_AFQ10, std_th_short_3_AFQ10]
std_list_AFQ100 = [std_th_short_0_AFQ100, std_th_short_1_AFQ100, std_th_short_2_AFQ100, std_th_short_3_AFQ100]
#std_list_AFQ1000 = [std_th_short_0_AFQ1000, std_th_short_1_AFQ1000, std_th_short_2_AFQ1000, std_th_short_3_AFQ1000]

x = list(range(len(std_list_HCS)))
total_width, n = 0.8, 3
width = total_width/n

plt.bar(x, std_list_HCS, width=width, label='HCS', fc = 'b')

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_AFQ10, width=width, label='AFQ10', fc = 'r', tick_label=group_list)

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_AFQ100, width=width, label='AFQ100', fc = 'g')

plt.legend()
plt.show()

# %%
#plt.figure(figsize=(15,8))
plt.xlabel("Scheduler Scheme")
plt.ylabel("Throughput Standard Devation")
plt.title("Throughput Standard Devation")
plt.legend()

#group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10"]
group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10", "AFQ:g=100"]
std_list_flow0 = [std_th_short_0_HCS, std_th_short_0_AFQ10, std_th_short_0_AFQ100, std_th_short_0_AFQ1000]
std_list_flow1 = [std_th_short_1_HCS, std_th_short_1_AFQ10, std_th_short_1_AFQ100, std_th_short_1_AFQ1000]
std_list_flow2 = [std_th_short_2_HCS, std_th_short_2_AFQ10, std_th_short_2_AFQ100, std_th_short_2_AFQ1000]
std_list_flow3 = [std_th_short_3_HCS, std_th_short_3_AFQ10, std_th_short_3_AFQ100, std_th_short_3_AFQ1000]

#std_list_HCS = [std_th_short_0_HCS, std_th_short_1_HCS, std_th_short_2_HCS, std_th_short_3_HCS]
#std_list_AFQ10 = [std_th_short_0_AFQ10, std_th_short_1_AFQ10, std_th_short_2_AFQ10, std_th_short_3_AFQ10]
#std_list_AFQ100 = [std_th_short_0_AFQ100, std_th_short_1_AFQ100, std_th_short_2_AFQ100, std_th_short_3_AFQ100]
#std_list_AFQ1000 = [std_th_short_0_AFQ1000, std_th_short_1_AFQ1000, std_th_short_2_AFQ1000, std_th_short_3_AFQ1000]

x = list(range(len(std_list_HCS)))
total_width, n = 0.8, 4
width = total_width/n

plt.bar(x, std_list_flow0, width=width, label='Flow 0', fc = 'r')

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow1, width=width, label='Flow 1', fc = 'b', tick_label=group_list)

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow2, width=width, label='Flow 2', fc = 'g')

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow3, width=width, label='Flow 3', fc = 'orange')

plt.legend()
plt.show()

# %%
std_th_com_0_HCS = np.std(th_com_0_HCS['Throughput'])
std_th_com_1_HCS = np.std(th_com_1_HCS['Throughput'])
std_th_com_2_HCS = np.std(th_com_2_HCS['Throughput'])
std_th_com_3_HCS = np.std(th_com_3_HCS['Throughput'])

std_th_com_0_AFQ10 = np.std(th_com_0_AFQ10['Throughput'])
std_th_com_1_AFQ10 = np.std(th_com_1_AFQ10['Throughput'])
std_th_com_2_AFQ10 = np.std(th_com_2_AFQ10['Throughput'])
std_th_com_3_AFQ10 = np.std(th_com_3_AFQ10['Throughput'])

std_th_com_0_AFQ100 = np.std(th_com_0_AFQ100['Throughput'])
std_th_com_1_AFQ100 = np.std(th_com_1_AFQ100['Throughput'])
std_th_com_2_AFQ100 = np.std(th_com_2_AFQ100['Throughput'])
std_th_com_3_AFQ100 = np.std(th_com_3_AFQ100['Throughput'])

std_th_com_0_AFQ1000 = np.std(th_com_0_AFQ1000['Throughput'])
std_th_com_1_AFQ1000 = np.std(th_com_1_AFQ1000['Throughput'])
std_th_com_2_AFQ1000 = np.std(th_com_2_AFQ1000['Throughput'])
std_th_com_3_AFQ1000 = np.std(th_com_3_AFQ1000['Throughput'])

# %%
#plt.figure(figsize=(15,8))
plt.xlabel("Scheduler Scheme")
plt.ylabel("Throughput Standard Devation Mid-tern")
plt.title("Throughput Standard Devation Mid-tern")
plt.legend()

#group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10"]
group_list = ["Gearbox", "AFQ:g=1", "AFQ:g=10", "AFQ:g=100"]
std_list_flow0 = [std_th_com_0_HCS, std_th_com_0_AFQ10, std_th_com_0_AFQ100, std_th_com_0_AFQ1000]
std_list_flow1 = [std_th_com_1_HCS, std_th_com_1_AFQ10, std_th_com_1_AFQ100, std_th_com_1_AFQ1000]
std_list_flow2 = [std_th_com_2_HCS, std_th_com_2_AFQ10, std_th_com_2_AFQ100, std_th_com_2_AFQ1000]
std_list_flow3 = [std_th_com_3_HCS, std_th_com_3_AFQ10, std_th_com_3_AFQ100, std_th_com_3_AFQ1000]

#std_list_HCS = [std_th_short_0_HCS, std_th_short_1_HCS, std_th_short_2_HCS, std_th_short_3_HCS]
#std_list_AFQ10 = [std_th_short_0_AFQ10, std_th_short_1_AFQ10, std_th_short_2_AFQ10, std_th_short_3_AFQ10]
#std_list_AFQ100 = [std_th_short_0_AFQ100, std_th_short_1_AFQ100, std_th_short_2_AFQ100, std_th_short_3_AFQ100]
#std_list_AFQ1000 = [std_th_short_0_AFQ1000, std_th_short_1_AFQ1000, std_th_short_2_AFQ1000, std_th_short_3_AFQ1000]

x = list(range(len(std_list_HCS)))
total_width, n = 0.8, 4
width = total_width/n

plt.bar(x, std_list_flow0, width=width, label='Flow 0', fc = 'r')

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow1, width=width, label='Flow 1', fc = 'b', tick_label=group_list)

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow2, width=width, label='Flow 2', fc = 'g')

for i in range(len(x)):
        x[i] = x[i] + width
plt.bar(x, std_list_flow3, width=width, label='Flow 3', fc = 'orange')

plt.ylim(0, 1200)

plt.legend()
plt.show()

# %%
th_short_0_HCS
# Out:
#       Timestamp  Throughput  Time Window
# 0          0.11        0.00         0.00
# 1          0.13       16.92         0.02
# 2          0.13      374.56         0.02
# 3          0.15      427.13         0.04
# 4          0.15      576.29         0.04
# 5          0.15      699.61         0.05
# 6          0.16      772.48         0.05
# 7          0.17      802.72         0.06
# 8          0.18      850.83         0.07
# 9          0.18      890.94         0.08
# 10         0.19      924.89         0.08
# 11         0.20     1176.47         0.07
# 12         0.20     1111.11         0.07
# 13         0.21     1290.32         0.06
# 14         0.21     1290.32         0.06
# 15         0.22     1290.32         0.06
# 16         0.23     1250.00         0.07
# 17         0.24     1250.00         0.07
# 18         0.24     1250.00         0.07
# 19         0.25     1290.32         0.06
# 20         0.25     1333.33         0.06
# 21         0.26     1379.31         0.06
# ...
