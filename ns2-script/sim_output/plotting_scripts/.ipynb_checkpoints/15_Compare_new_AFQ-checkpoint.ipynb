# %% [markdown]
# # This script plot the output of test 15_Compare_tcp_new_AFQ

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from collections import OrderedDict
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3*2Mbps link + 12 Mbps link tcp

# %% [markdown]
# ### HCS

# %%
th_0_HCS = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/HCS/throughput_0.txt', header=None)
th_0_HCS.columns = ['Timestamp', 'Throughput']

th_1_HCS = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/HCS/throughput_1.txt', header=None)
th_1_HCS.columns = ['Timestamp', 'Throughput']

th_2_HCS = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/HCS/throughput_2.txt', header=None)
th_2_HCS.columns = ['Timestamp', 'Throughput']

th_3_HCS = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/HCS/throughput_3.txt', header=None)
th_3_HCS.columns = ['Timestamp', 'Throughput']

# %%
th_0_HCS.head()
# Out:
#    Timestamp  Throughput
# 0       0.11        0.00
# 1       0.13       16.92
# 2       0.13      343.58
# 3       0.15      427.13
# 4       0.15      576.29

# %%
print("th0_HCS.shape = ", th_0_HCS.shape)
print("th1_HCS.shape = ", th_1_HCS.shape)
print("th2_HCS.shape = ", th_2_HCS.shape)
print("th3_HCS.shape = ", th_3_HCS.shape)
# Out:
# th0_HCS.shape =  (1448, 2)
# th1_HCS.shape =  (1448, 2)
# th2_HCS.shape =  (1447, 2)
# th3_HCS.shape =  (1454, 2)

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of HCS_1m")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_HCS['Timestamp'], th_0_HCS['Throughput'], color='red', label='th0_HCS')
plt.plot(th_1_HCS['Timestamp'], th_1_HCS['Throughput'], color='blue', label='th1_HCS')
plt.plot(th_2_HCS['Timestamp'], th_2_HCS['Throughput'], color='green', label='th2_HCS')
plt.plot(th_3_HCS['Timestamp'], th_3_HCS['Throughput'], color='orange', label='th3_HCS')

# %% [markdown]
# # AFQ10

# %%
th_0_AFQ10 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ10/throughput_0.txt', header=None)
th_0_AFQ10.columns = ['Timestamp', 'Throughput']

th_1_AFQ10 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ10/throughput_1.txt', header=None)
th_1_AFQ10.columns = ['Timestamp', 'Throughput']

th_2_AFQ10 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ10/throughput_2.txt', header=None)
th_2_AFQ10.columns = ['Timestamp', 'Throughput']

th_3_AFQ10 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ10/throughput_3.txt', header=None)
th_3_AFQ10.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ10")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_AFQ10['Timestamp'], th_0_AFQ10['Throughput'], color='red', label='th0_AFQ10')
plt.plot(th_1_AFQ10['Timestamp'], th_1_AFQ10['Throughput'], color='blue', label='th1_AFQ10')
plt.plot(th_2_AFQ10['Timestamp'], th_2_AFQ10['Throughput'], color='green', label='th2_AFQ10')
plt.plot(th_3_AFQ10['Timestamp'], th_3_AFQ10['Throughput'], color='orange', label='th3_AFQ10')

# %% [markdown]
# ### AFQ100

# %%
th_0_AFQL100 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ100/throughput_0.txt', header=None)
th_0_AFQL100.columns = ['Timestamp', 'Throughput']

th_1_AFQL100 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ100/throughput_1.txt', header=None)
th_1_AFQL100.columns = ['Timestamp', 'Throughput']

th_2_AFQL100 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ100/throughput_2.txt', header=None)
th_2_AFQL100.columns = ['Timestamp', 'Throughput']

th_3_AFQL100 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ100/throughput_3.txt', header=None)
th_3_AFQL100.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ100")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_AFQL100['Timestamp'], th_0_AFQL100['Throughput'], color='red', label='th0_AFQ100')
plt.plot(th_1_AFQL100['Timestamp'], th_1_AFQL100['Throughput'], color='blue', label='th1_AFQ100')
plt.plot(th_2_AFQL100['Timestamp'], th_2_AFQL100['Throughput'], color='green', label='th2_AFQ100')
plt.plot(th_3_AFQL100['Timestamp'], th_3_AFQL100['Throughput'], color='orange', label='th3_AFQ100')

# %% [markdown]
# ### AFQ1000

# %%
th_0_AFQL1000 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ1000/throughput_0.txt', header=None)
th_0_AFQL1000.columns = ['Timestamp', 'Throughput']

th_1_AFQL1000 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ1000/throughput_1.txt', header=None)
th_1_AFQL1000.columns = ['Timestamp', 'Throughput']

th_2_AFQL1000 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ1000/throughput_2.txt', header=None)
th_2_AFQL1000.columns = ['Timestamp', 'Throughput']

th_3_AFQL1000 = pd.read_table('../15_compare_new_AFQ/2-12m-tcp/AFQ1000/throughput_3.txt', header=None)
th_3_AFQL1000.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQ100")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_AFQL100['Timestamp'], th_0_AFQL100['Throughput'], color='red', label='th0_AFQL100')
plt.plot(th_1_AFQL100['Timestamp'], th_1_AFQL100['Throughput'], color='blue', label='th1_AFQL100')
plt.plot(th_2_AFQL100['Timestamp'], th_2_AFQL100['Throughput'], color='green', label='th2_AFQL100')
plt.plot(th_3_AFQL100['Timestamp'], th_3_AFQL100['Throughput'], color='orange', label='th3_AFQL100')

# %% [markdown]
# ### DropTail with 1Mbps cbr

# %%
th_0_DropTail_1m = pd.read_table('../12_Compare_cbr/outputs/DropTail_1m/throughput_0.txt', header=None)
th_0_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_1_DropTail_1m = pd.read_table('../12_Compare_cbr/outputs/DropTail_1m/throughput_1.txt', header=None)
th_1_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_2_DropTail_1m = pd.read_table('../12_Compare_cbr/outputs/DropTail_1m/throughput_2.txt', header=None)
th_2_DropTail_1m.columns = ['Timestamp', 'Throughput']

th_3_DropTail_1m = pd.read_table('../12_Compare_cbr/outputs/DropTail_1m/throughput_3.txt', header=None)
th_3_DropTail_1m.columns = ['Timestamp', 'Throughput']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Time(sec)")
plt.ylabel("Throughput(bps)")
plt.title("Throughput of AFQL1000")
plt.legend()
line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#type(th_0_HCS)
plt.plot(th_0_DropTail_1m['Timestamp'], th_0_DropTail_1m['Throughput'], color='red', label='th0_AFQL100')
plt.plot(th_1_DropTail_1m['Timestamp'], th_1_DropTail_1m['Throughput'], color='blue', label='th1_AFQL100')
plt.plot(th_2_DropTail_1m['Timestamp'], th_2_DropTail_1m['Throughput'], color='green', label='th2_AFQL100')
plt.plot(th_3_DropTail_1m['Timestamp'], th_3_DropTail_1m['Throughput'], color='orange', label='th3_AFQL100')

# %% [markdown]
# ## Delay
#
# ### HCS

# %%
delay_0_HCS_1m = pd.read_table('../12_Compare_cbr/outputs/HCS_5-1m/delay_0.txt', header=None)
delay_0_HCS_1m.columns = ['Packet_Seq', 'Delay']

delay_1_HCS_1m = pd.read_table('../12_Compare_cbr/outputs/HCS_5-1m/delay_1.txt', header=None)
delay_1_HCS_1m.columns = ['Packet_Seq', 'Delay']

delay_2_HCS_1m = pd.read_table('../12_Compare_cbr/outputs/HCS_5-1m/delay_2.txt', header=None)
delay_2_HCS_1m.columns = ['Packet_Seq', 'Delay']

delay_3_HCS_1m = pd.read_table('../12_Compare_cbr/outputs/HCS_5-1m/delay_3.txt', header=None)
delay_3_HCS_1m.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay HCS")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
#plt.ylim(0, 0.2)
plt.plot(delay_0_HCS_1m['Packet_Seq'], delay_0_HCS_1m['Delay'], color='red', label='delay0_HCS')
plt.plot(delay_1_HCS_1m['Packet_Seq'], delay_1_HCS_1m['Delay'], color='blue', label='delay1_HCS')
plt.plot(delay_2_HCS_1m['Packet_Seq'], delay_2_HCS_1m['Delay'], color='green', label='delay2_HCS')
plt.plot(delay_3_HCS_1m['Packet_Seq'], delay_3_HCS_1m['Delay'], color='orange', label='delay3_HCS')

# %% [markdown]
# ### AFQ10

# %%
delay_0_AFQ10 = pd.read_table('../11_Compare/outputs/AFQ10/delay_0.txt', header=None)
delay_0_AFQ10.columns = ['Packet_Seq', 'Delay']

delay_1_AFQ10 = pd.read_table('../11_Compare/outputs/AFQ10/delay_1.txt', header=None)
delay_1_AFQ10.columns = ['Packet_Seq', 'Delay']

delay_2_AFQ10 = pd.read_table('../11_Compare/outputs/AFQ10/delay_2.txt', header=None)
delay_2_AFQ10.columns = ['Packet_Seq', 'Delay']

delay_3_AFQ10 = pd.read_table('../11_Compare/outputs/AFQ10/delay_3.txt', header=None)
delay_3_AFQ10.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQ10")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
plt.ylim(0, 0.2)
plt.plot(delay_0_AFQ10['Packet_Seq'], delay_0_AFQ10['Delay'], color='red', label='delay0_AFQ10')
plt.plot(delay_1_AFQ10['Packet_Seq'], delay_1_AFQ10['Delay'], color='blue', label='delay1_AFQ10')
plt.plot(delay_2_AFQ10['Packet_Seq'], delay_2_AFQ10['Delay'], color='green', label='delay2_AFQ10')
plt.plot(delay_3_AFQ10['Packet_Seq'], delay_3_AFQ10['Delay'], color='orange', label='delay3_AFQ10')

# %% [markdown]
# ### AFQ100

# %%
delay_0_AFQL100 = pd.read_table('../11_Compare/outputs/AFQL100/delay_0.txt', header=None)
delay_0_AFQL100.columns = ['Packet_Seq', 'Delay']

delay_1_AFQL100 = pd.read_table('../11_Compare/outputs/AFQL100/delay_1.txt', header=None)
delay_1_AFQL100.columns = ['Packet_Seq', 'Delay']

delay_2_AFQL100 = pd.read_table('../11_Compare/outputs/AFQL100/delay_2.txt', header=None)
delay_2_AFQL100.columns = ['Packet_Seq', 'Delay']

delay_3_AFQL100 = pd.read_table('../11_Compare/outputs/AFQL100/delay_3.txt', header=None)
delay_3_AFQL100.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQL100")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
plt.ylim(0, 0.2)
plt.plot(delay_0_AFQL100['Packet_Seq'], delay_0_AFQL100['Delay'], color='red', label='delay0_AFQL100')
plt.plot(delay_1_AFQL100['Packet_Seq'], delay_1_AFQL100['Delay'], color='blue', label='delay1_AFQL100')
plt.plot(delay_2_AFQL100['Packet_Seq'], delay_2_AFQL100['Delay'], color='green', label='delay2_AFQL100')
plt.plot(delay_3_AFQL100['Packet_Seq'], delay_3_AFQL100['Delay'], color='orange', label='delay3_AFQL100')

# %% [markdown]
# ### AFQ1000

# %%
delay_0_AFQL1000 = pd.read_table('../11_Compare/outputs/AFQL1000/delay_0.txt', header=None)
delay_0_AFQL1000.columns = ['Packet_Seq', 'Delay']

delay_1_AFQL1000 = pd.read_table('../11_Compare/outputs/AFQL1000/delay_1.txt', header=None)
delay_1_AFQL1000.columns = ['Packet_Seq', 'Delay']

delay_2_AFQL1000 = pd.read_table('../11_Compare/outputs/AFQL1000/delay_2.txt', header=None)
delay_2_AFQL1000.columns = ['Packet_Seq', 'Delay']

delay_3_AFQL1000 = pd.read_table('../11_Compare/outputs/AFQL1000/delay_3.txt', header=None)
delay_3_AFQL1000.columns = ['Packet_Seq', 'Delay']

# %%
plt.figure(figsize=(15,8))
plt.xlabel("Packet Sequence")
plt.ylabel("Delay(sec)")
plt.title("Delay AFQL1000")
plt.legend()
#line = plt.axhline(y=1000, xmin=0, xmax=12, linewidth=2, color = 'violet')
line.set_dashes((10, 4))
plt.ylim(0, 0.2)
plt.plot(delay_0_AFQL1000['Packet_Seq'], delay_0_AFQL1000['Delay'], color='red', label='delay0_AFQL100')
plt.plot(delay_1_AFQL1000['Packet_Seq'], delay_1_AFQL1000['Delay'], color='blue', label='delay1_AFQL100')
plt.plot(delay_2_AFQL1000['Packet_Seq'], delay_2_AFQL1000['Delay'], color='green', label='delay2_AFQL100')
plt.plot(delay_3_AFQL1000['Packet_Seq'], delay_3_AFQL1000['Delay'], color='orange', label='delay3_AFQL100')
